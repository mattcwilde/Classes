# %% [markdown]
# # Lab B3
#
# ## Matt Wilde
#
# # 3 Spectral lines from the solar atmosphere
#
# ## 3.1 Observed Na D line profiles
#
# * ** Pull the data that went into making Figure 8 over from ftp://vso.nso.edu/pub/atlas/visatl. Concatenate the files covering the two Na I D lines (sp16900 and sp16950) into a single file, deleting the overlaps.**

# %%
# first import everything
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import astropy.constants as const

#use the pretty LaTeX fonts
mpl.rcParams.update({'text.usetex': True})
plt.rc('font', family='serif', size=15)
#mpl.rc('axes.formatter', useoffset=False)

# plt.style.use('ggplot')

# %% [markdown]
# * **Write IDL code to read these data. You need the first and third columns (see the README)**

# %%
freq, telluric, spec, corrspec = np.loadtxt('NaD.dat', unpack=True)

# %% [markdown]
# ## 3.2 Na D wavelengths

# %% [markdown]
# * **Plot the solar Na I D lines against vacuum wavelength at various dispersions.**

# %%
wave = 1/freq

plt.figure(figsize=(8,8))
plt.plot(wave, spec)
plt.xlabel('vacuum wavelength')
plt.ylabel('normalized flux')
plt.title('Na I D in vacuum')
plt.show()


fig, ax = plt.subplots(ncols=3)

ax[0].plot(wave, spec)
ax[0].set_xlabel('vacuum wavelength')
ax[0].set_ylabel('normalized flux')
ax[0].set_title('Na I D in vacuum')

ax[1].plot(wave[::50], spec[::50])
ax[1].set_xlabel('vacuum wavelength')
ax[1].set_ylabel('normalized flux')
ax[1].set_title('Na I D in vacuum')


ax[2].plot(wave[::50], spec[::50])
ax[2].set_xlabel('vacuum wavelength')
ax[2].set_ylabel('normalized flux')
ax[2].set_title('Na I D in vacuum')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-0631d0659e82> in <module>()
#      15 ax[0].set_ylabel('normalized flux')
#      16 ax[0].set_title('Na I D in vacuum')
# ---> 17 ax[0].show()
#      18
#      19 ax[1].plot(wave[::50], spec[::50])
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
plt.figure(figsize=(8,8))
plt.plot(wave[::10], spec[::10])
plt.plot(wave[::100], spec[::100])
plt.plot(wave[::200], spec[::200])
plt.xlabel('vacuum wavelength')
plt.ylabel('normalized flux')
plt.title('Na I D in vacuum')
plt.show()
